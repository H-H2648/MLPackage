# %%
import numpy as np
from ...LinRegg import LinRegg
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-2cc2f2684575> in <module>
#       1 import numpy as np
# ----> 2 from ...LinRegg import LinRegg
#
# ImportError: attempted relative import with no known parent package

# %%
def standardize(X):
    meanX = np.mean(X, axis = 0)
    stdX = np.std(X, axis = 0)
    #meanY = np.mean(Y)
    #standardizedY = Y - meanY
    standardizedX = (X - meanX)/stdX
    return standardizedX
    #return (standardizedX, standardizedY)

# %%
X = np.loadtxt('prostate.data.txt', skiprows=1)
y = X[:,-1]
X = X[:,0:-1]
X = standardize(X)
#X, y = standardize(X, y)
print(X)
print(y)
# Out:
# [[-1.64586143 -2.01663373 -1.87210098 -1.03002898 -0.52565748 -0.86765522
#   -1.04757113 -0.86895727]
#  [-1.9993129  -0.72575948 -0.79198919 -1.03002898 -0.52565748 -0.86765522
#   -1.04757113 -0.86895727]
#  [-1.58702059 -2.20015441  1.36823439 -1.03002898 -0.52565748 -0.86765522
#    0.34440695 -0.15615511]
#  [-2.17817387 -0.8121913  -0.79198919 -1.03002898 -0.52565748 -0.86765522
#   -1.04757113 -0.86895727]
#  [-0.5105128  -0.46121762 -0.25193329 -1.03002898 -0.52565748 -0.86765522
#   -1.04757113 -0.86895727]
#  [-2.04670586 -0.93880639 -1.87210098 -1.03002898 -0.52565748 -0.86765522
#   -1.04757113 -0.86895727]
#  [-0.5226677  -0.3646778   0.01809466  0.35670122 -0.52565748 -0.86765522
#   -1.04757113 -0.86895727]
#  [-0.56020767 -0.20984103 -0.79198919  0.99529051 -0.52565748 -0.86765522
#   -1.04757113 -0.86895727]
#  [-1.81362657 -0.20984103 -2.2771429  -1.03002898 -0.52565748 -0.86765522
#   -1.04757113 -0.86895727]
# ...

# %%
Xtrain, Xtest = X[:67], X[67:]
ytrain, ytest = y[:67], y[67:]
prostateLinTest = LinRegg(Xtrain, ytrain)
print(prostateLinTest.residual())
# Out:
# [-0.4307829 -0.1625189 -0.1625189 -0.1625189  0.3715636  0.7654678
#   0.7654678  0.8544153  1.047319   1.047319   1.2669476  1.2669476
#   1.2669476  1.3480731  1.3987169  1.446919   1.4701758  1.4929041
#   1.5581446  1.5993876  1.6389967  1.6582281  1.6956156  1.7137979
#   1.7316555  1.7664417  1.8000583  1.8164521  1.8484548  1.8946169
#   1.9242487  2.008214   2.008214   2.0215476  2.0476928  2.0856721
#   2.1575593  2.1916535  2.2137539  2.2772673  2.2975726  2.3075726
#   2.3272777  2.3749058  2.5217206  2.5533438  2.5687881  2.5687881
#   2.5915164  2.5915164  2.6567569  2.677591   2.6844403  2.6912431
#   2.7047113  2.7180005  2.7880929  2.7942279  2.8063861  2.8124102
#   2.8419982  2.8535925  2.8535925  2.8820035  2.8820035  2.8875901
#   2.9204698]
# [-1.23148355e+00 -8.94787712e-01 -6.44653364e-01 -7.81800633e-01
#  -1.08821361e+00 -9.34235605e-02 -9.78183017e-01 -1.20632575e+00
#  -1.85926441e-01 -4.78475812e-02  2.13849861e-03  2.35189483e-01
# ...

# %%
prostateLinTest.RSSSolve()
print(prostateLinTest.bestFit)
# Out:
# [ 2.08662206  0.51335616  0.24490627 -0.18806252  0.22877726 -0.12415261
#  -0.14986581  0.17503238  0.08686458]

# %%
for ii in range(prostateLinTest.p + 1):
    print(prostateLinTest.zScore(ii))
# Out:
# 23.6495219898485
# 4.867961347670616
# 2.5655123236950383
# -2.2065974149550103
# 2.45409402123062
# -0.7953977534004019
# -1.1259548108248298
# 1.4767572879604665
# 0.6699867749061259

# %%
print(prostateLinTest.FTest([5, 8]))
# Out:
# [-0.4307829 -0.1625189 -0.1625189 -0.1625189  0.3715636  0.7654678
#   0.7654678  0.8544153  1.047319   1.047319   1.2669476  1.2669476
#   1.2669476  1.3480731  1.3987169  1.446919   1.4701758  1.4929041
#   1.5581446  1.5993876  1.6389967  1.6582281  1.6956156  1.7137979
#   1.7316555  1.7664417  1.8000583  1.8164521  1.8484548  1.8946169
#   1.9242487  2.008214   2.008214   2.0215476  2.0476928  2.0856721
#   2.1575593  2.1916535  2.2137539  2.2772673  2.2975726  2.3075726
#   2.3272777  2.3749058  2.5217206  2.5533438  2.5687881  2.5687881
#   2.5915164  2.5915164  2.6567569  2.677591   2.6844403  2.6912431
#   2.7047113  2.7180005  2.7880929  2.7942279  2.8063861  2.8124102
#   2.8419982  2.8535925  2.8535925  2.8820035  2.8820035  2.8875901
#   2.9204698]
# False

# %%
print(prostateLinTest.orthogonalizationAlgorithm())
# Out:
# [ 1.92099448 -1.41936087  0.14642017 -0.79348636  1.43065957 -0.09214463
#   3.37420173  2.02208075  0.88747007]
